# %% [markdown]
# # World Gas Prices Dataset ML Project

# %%
#Importing all the libraries that we need.
import numpy as np
import pandas as pd
from matplotlib import pyplot as mp
import seaborn as sb
# %matplotlib inline

# %%
#importing our dataset.
gas_price=pd.read_csv('gas_prices.csv')

# %%
# show datasite head 5 rows 
gas_price.head(60)
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
# show datasite shape
gas_price.shape
# Out:
# (19, 11)

# %%
#checking for null values.
gas_price.isnull().sum()
# Out:
# Year           0
# Australia      1
# Canada         0
# France         0
# Germany        0
# Italy          0
# Japan          0
# Mexico         0
# South Korea    0
# UK             0
# USA            0
# dtype: int64

# %%
mp.figure(figsize=(12,8))
mp.title('Bar Chart Gas',color='black',size=25)
mp.xlabel('Year',size=15)
mp.ylabel('Country',size=15)
mp.grid()
mp.plot(gas_price.Year,gas_price.USA,'d--',label='USA')
mp.plot(gas_price.Year,gas_price.Canada,'b--',label='Canada')
mp.plot(gas_price.Year,gas_price.Australia,'r--',label='Australia')
mp.plot(gas_price.Year,gas_price.France,'g--',label='France')
mp.plot(gas_price.Year,gas_price.Germany,'m--',label='Germany')
mp.plot(gas_price.Year,gas_price.Italy,'p--',label='Italy')
mp.plot(gas_price.Year,gas_price.Japan,'o--',label='Japan')
mp.plot(gas_price.Year,gas_price.Mexico,'d--',label='Mexico')
mp.plot(gas_price.Year,gas_price['South Korea'],'c--',label='South Korea')
mp.plot(gas_price.Year,gas_price.UK,'k--',label='UK')
mp.xticks(gas_price.Year[::2])
mp.legend()
mp.show()

# %%
# show datasite all describe vlaues
gas_price.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
# show datasite head 5 rows 
gas_price.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
#Apply ML Algorithm

# %%
#Divide by variable
x=gas_price[['Year']]
y=gas_price[['Japan']]

# %%
#import ML Algorithm
from sklearn.model_selection import train_test_split as sp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
xtrain,xtest,ytrain,ytest=sp(x,y,train_size=.70,random_state=1)

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.predict([[2009]])
# Out:
# array([[4.46713753]])

# %%
ypred=lr.predict(xtest)

# %%
mean_squared_error(ytest,ypred)
# Out:
# 0.13538222149120563

# %%
mean_absolute_error(ytest,ypred)
# Out:
# 0.27299167598459717
